# %%
from keras.models import load_model

# %%
m= load_model('facedetect.h5')

# %%
from keras.preprocessing import image

# %%
timage= image.load_img('D://faces//test//dhyey_test//10.jpg',target_size=(224,224,3))

# %%
type(timage)
# Out:
# PIL.Image.Image

# %%
timage
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2B38DDDE088>

# %%
timage= image.img_to_array(timage)

# %%
import numpy as np

# %%
timg= np.expand_dims(timage,axis=0)

# %%
timg.shape
# Out:
# (1, 224, 224, 3)

# %%
result= m.predict(timg)

# %%
result
# Out:
# array([[1., 0.]], dtype=float32)
